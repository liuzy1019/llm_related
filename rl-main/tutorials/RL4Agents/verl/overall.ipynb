# %% [markdown]
# ### `fsdp_workers.py` vs. `dp_actor.py`

# %% [markdown]
# - dp_actor: `DataParallelPPOActor` => actor 对象
#     - actor.update_policy
#     - ppo 算法执行
# - fsdp_workers: `ActorRolloutRefWorker`
#     - 聚焦分布式系统的关系
#     - `from torch.distributed.fsdp import FullyShardedDataParallel as FSDP`
