# %% [markdown]
# - https://verl.readthedocs.io/en/latest/start/agentic_rl.html
# - https://verl.readthedocs.io/en/latest/advance/agent_loop.html
# - multi-turn(w/ tool call) 是 agent（loop）的基石

# %% [markdown]
# ```sh
# pip install pytest-asyncio
# pytest -s tests/experimental/agent_loop/test_basic_agent_loop.py
# ```
