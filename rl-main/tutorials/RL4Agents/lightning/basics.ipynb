# %% [markdown]
# - 训练与执行的“紧耦合”困境
#     - Agent Lightning 的核心贡献在于提出了一个完全解耦的框架，旨在用 RL 训练任何（ANY）AI Agent，而几乎不需要修改 Agent 的现有代码。
# - training framework: distributed client-server architecture
#     - This separation allows for **scalable data generation across multiple clients** while **centralizing the computationally intensive model training on a dedicated server with GPUs**, and also provides opportunities for customizing algorithms and training strategies (like prompt optimization) with minimal code changes.
# - Training Server (agentlightning.verl)
#     - The server, launched with the first command below, manages the core training loop.
#     - It runs an RL algorithm (with verl of course) and **hosts an OpenAI-compatible LLM endpoint** (with **verl’s async server**).
#     - The server’s sole purpose is to receive interaction data from clients and update the LLM’s weights to improve its performance.
# - tutorials
#     - https://medium.com/@yugez/training-ai-agents-to-write-and-self-correct-sql-with-reinforcement-learning-571ed31281ad
#         - 经典的监督微调将 SQL 生成视为一次性任务。在这里，智能体通过与数据库和环境的交互学习自我纠正，并且强化学习使用基于结果的奖励来更新写入和重写策略。这闭合了意图、执行、反馈和策略改进之间的循环。
