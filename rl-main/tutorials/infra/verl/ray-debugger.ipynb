# %% [markdown]
# - 如果 dashboard port 冲突
#     - Failed to bind to 0.0.0.0:8265 because it's already occupied. You can use `ray start --dashboard-port ...` or `ray.init(dashboard_port=...)` to select a different port.
#     - 出现在 slurm 集群环境下；
#
# ```shell
# ray start --head --ray-debugger-external --port 6380 --dashboard-host 0.0.0.0 --dashboard-port 8266
# ```
# - 新的 dashboard-port 为 ray-distributed-debugger 配置 的 cluser port
#     - `127.0.0.1:8266`（默认是 8265）
