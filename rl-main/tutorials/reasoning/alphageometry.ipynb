# %%
from IPython.display import Image

# %% [markdown]
# ### DDAR

# %% [markdown]
# ### synthetic data

# %% [markdown]
# - step 1: sample $a=b, b=c$
# - step 2: deduce $a=c$
# - step 3: serialize
# ```
# Theorem: Let a=b and b=c. Prove: a=c.
# Proof: apply transitivity of equality on a=b & b=c.
# ```
#
# - data format
#     - theorem - proof strings.
# - 91% pure deduction, 9% with auxiliary：
#     - 91% （纯推演）用于预训练，9%（需要引入辅助线）用于微调

# %%
Image(url='./imgs/ag_data.png', width=400)
# Out:
# <img src="./imgs/ag_data.png" width="400"/>
